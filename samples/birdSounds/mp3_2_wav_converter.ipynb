# %%
import os 
from os import path
import subprocess
import pydub
from pydub import AudioSegment
import glob
import pandas as pd

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import librosa
import librosa.display
import scipy
import cv2

# %%
def create_balckwhite_128(librosa_audio_data, number_of_windows_per_file = 1305):
    
    pic = np.ones(shape=(128,number_of_windows_per_file), dtype=float)*255.0
    for i in range(0,number_of_windows_per_file):
        #multiplying fileds 1 and 2 with 1000 to change them to msec
        #I am using 23 here, because the hop_length is 23
        if((float(librosa_audio_data[1])*1000)<=(i*23) and (i*23 + 46)<float(librosa_audio_data[2])*1000):
            for k in range(0,128):
                pic[k][i]=0 #because we want the balckwhite picture to be in the middle
    return pic

# %%
def build_spectrogram_annotate(audio_file_path, i=0, img_path = "img_spectrogram", windows_size = 256, annotationFormat="image"):
    y, sr = librosa.load(audio_file_path, sr=44100)
    S=librosa.feature.melspectrogram(y, sr=44100, n_mels=128, n_fft=2028, hop_length=1014)
    log_S = librosa.power_to_db(S, ref=np.max)

    log_S =np.abs(log_S)/ np.max(np.abs(log_S),axis=0)
    log_S *= (255.0 )
    spectogram_img_path = os.path.join(img_path,"/".join(audio_file_path.split("/")[1:-1]))
    os.makedirs(spectogram_img_path,exist_ok=True) # Extract folder name & create folder if not already existing  : img_spectrogram/Common Whitethroat
    # spectogram_img_path = os.path.join(img_path,"/".join(audio_file_path.split("/")[1:]))[:-4]
    img = log_S[:,:windows_size]
    # img = cv2.resize(log_S, (128, windows_size))
    cv2.imwrite(spectogram_img_path+'/'+str(i)+'.png', img)
    # imageio.imwrite(spectogram_img_path+'/'+str(i)+'.png', log_S)

    
    # annotation
    if annotationFormat=="image":
        # imageio.imwrite(directory_name+'/'+str(i)+'.png', p)
        p = create_balckwhite_128(y, windows_size)
        directory_name = os.path.join(spectogram_img_path,str(i))
    
        os.makedirs(directory_name,exist_ok=True)
        cv2.imwrite(directory_name+'/'+str(i)+'.png', p)

# %% [markdown]
# ## Convert mp3 to wav and build spectrogram

# %% [markdown]
# ## Use little sample

# %%
annotation_template = """
<annotation>
	<folder>{folderName}</folder>
	<filename>{imageName}</filename>
	<path>{fullNamePath}</path>
	<source>
		<database>Unknown</database>
	</source>
	<size>
		<width>{imgWidth}</width>
		<height>{imgHeight}</height>
		<depth>{channel}</depth>
	</size>
	<segmented>0</segmented>
	<object>
		<name>{className}</name>
		<pose>Unspecified</pose>
		<truncated>0</truncated>
		<difficult>0</difficult>
		<bndbox>
			<xmin>{bbox_xmin}</xmin>
			<ymin>{bbox_ymin}</ymin>
			<xmax>{bbox_xmax}</xmax>
			<ymax>{bbox_ymax}</ymax>
		</bndbox>
	</object>
</annotation>
"""

# %%
# !rm -R audio_wav/*
# !rm -R temp_datasets/*
# !rm -R temp_datasets/annots/*

# %%
folder_path = "audio_mp3/**"
dest_folder = "audio_wav"
i = 0
data_list = []
samples = 5
img_path = "temp_datasets"
windows_size = 256
n_mels = 128

# %%
# meta_info = {}
for path2file in glob.glob(folder_path):
    # print(path2file)
    cnt = 0
    for files in glob.glob(path2file+"/*.mp3"):
        if(cnt>samples-1):
            break
        temp = files.split(".mp3")[0] # discard the extension
        temp = temp.split("-")
        id = temp[-1]
        classe = temp[-2].split("/")[-1]
        meta_info = {
        "id":i,
        "audio_id":id,
        "class":classe,
        "t_start_sec":"0",
        "t_end_sec":"5"
        }   
        
        new_path = os.path.join(dest_folder, classe)
        os.makedirs(new_path,exist_ok=True)
        data_list.append(meta_info)
        audio_file_path = os.path.join(new_path, str(id + ".wav"))
        subprocess.call([pydub.AudioSegment.converter, '-i', files,audio_file_path])        
        build_spectrogram_annotate(audio_file_path, i, img_path+"/images", windows_size, annotationFormat=None)

        directory_name = os.path.join(img_path,"annots")
    
        os.makedirs(directory_name,exist_ok=True)
        with open(directory_name+'/'+str(i)+'.xml',"w") as fp:
            fp.write(annotation_template.format(folderName = img_path,
                                                imageName =str(i)+".png",
                                                fullNamePath =img_path+"/"+str(i)+".png",
                                                imgWidth = windows_size,
                                                imgHeight = n_mels,
                                                channel = 1,
                                                className = classe.replace(" ","_"),
                                                bbox_xmin = 1,
                                                bbox_ymin = 1,
                                                bbox_xmax = windows_size-1,
                                                bbox_ymax = n_mels-1)
                    )
            fp.close()
        cnt+=1
        i+=1
# Out:
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Common Whitethroat/Common Whitethroat-199781.mp3':
#   Metadata:
#     title           : Common Whitethroat (Sylvia communis)
#     genre           : Sylviidae
#     artist          : david m
#     album           : xeno-canto
#     TIT1            : wleczh
#     comment         : XC199781 © david m // Ryedale District (near  Helperthorpe), North Yorkshire, England (54.12, -0.5445), United Kingdom // 80m // 05:20h, 2014-07-07 // male, song // Whitethroat song soundscape ... not filtered ... open lavalier mics fastened to bush ...
#     copyright       : 2014 david m
#   Duration: 00:04:12.65, start: 0.023021, bitrate: 320 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 320 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Whitethroat/199781.wav':
#   Metadata:
#     INAM            : Common Whitethroat (Sylvia communis)
#     IGNR            : Sylviidae
#     IART            : david m
#     IPRD            : xeno-canto
#     TIT1            : wleczh
#     ICMT            : XC199781 © david m // Ryedale District (near  Helperthorpe), North Yorkshire, England (54.12, -0.5445), United Kingdom // 80m // 05:20h, 2014-07-07 // male, song // Whitethroat song soundscape ... not filtered ... open lavalier mics fastened to bush ...
#     ICOP            : 2014 david m
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=   47368kB time=00:04:12.62 bitrate=1536.0kbits/s speed= 546x
# video:0kB audio:47367kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001344%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-0.00222158  0.01347588  0.04387941 ...  0.0066013   0.00791453
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# [mp3 @ 0x55f15bf9a680] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'audio_mp3/Common Whitethroat/Common Whitethroat-492805.mp3':
#   Metadata:
#     title           : Common Whitethroat (Sylvia communis communis)
#     genre           : Sylviidae
#     artist          : Frank Lambert
#     album           : xeno-canto
#     TIT1            : wleczh
#     comment         : XC492805 Â© Frank Lambert // Fen End Farm,  (near  Cottenham), Cambridgeshire, England (52.3143, 0.1248), United Kingdom // 0m // 06:25h, 2019-07-25 // song //  /  / bird-seen:no /  / playback-used:no
#   Duration: 00:02:56.94, start: 0.000000, bitrate: 320 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 320 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Whitethroat/492805.wav':
#   Metadata:
#     INAM            : Common Whitethroat (Sylvia communis communis)
#     IGNR            : Sylviidae
#     IART            : Frank Lambert
#     IPRD            : xeno-canto
#     TIT1            : wleczh
#     ICMT            : XC492805 Â© Frank Lambert // Fen End Farm,  (near  Cottenham), Cambridgeshire, England (52.3143, 0.1248), United Kingdom // 0m // 06:25h, 2019-07-25 // song //  /  / bird-seen:no /  / playback-used:no
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=   30479kB time=00:02:56.92 bitrate=1411.2kbits/s speed= 562x
# video:0kB audio:30478kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001294%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Common Whitethroat/Common Whitethroat-619033.mp3':
#   Metadata:
#     title           : Common Whitethroat (Sylvia communis communis)
#     genre           : Sylviidae
#     artist          : david m
#     album           : xeno-canto
#     TIT1            : wleczh
#     comment         : XC619033 Â© david m // Ryedale District, (near  Helperthorpe), North Yorkshire, England (54.1228, -0.5428), United Kingdom // 80m // 06:49h, 2020-07-22 // adult, call, sex uncertain // Whitethroat call ... dpa 4060s in parabolic to MixPre3 ... not edite
#   Duration: 00:03:06.82, start: 0.023021, bitrate: 320 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 320 kb/s
#     Metadata:
#       encoder         : LAME3.100
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Whitethroat/619033.wav':
#   Metadata:
#     INAM            : Common Whitethroat (Sylvia communis communis)
#     IGNR            : Sylviidae
#     IART            : david m
#     IPRD            : xeno-canto
#     TIT1            : wleczh
#     ICMT            : XC619033 Â© david m // Ryedale District, (near  Helperthorpe), North Yorkshire, England (54.1228, -0.5428), United Kingdom // 80m // 06:49h, 2020-07-22 // adult, call, sex uncertain // Whitethroat call ... dpa 4060s in parabolic to MixPre3 ... not edite
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=   35021kB time=00:03:06.77 bitrate=1536.0kbits/s speed= 464x
# video:0kB audio:35020kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001684%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[0.0003791  0.00031996 0.00050045 ... 0.00093941 0.0010935  0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Common Whitethroat/Common Whitethroat-256109.mp3':
#   Metadata:
#     title           : Common Whitethroat (Sylvia communis)
#     genre           : Sylviidae
#     artist          : Anthony McGeehan
#     album           : xeno-canto
#     TIT1            : wleczh
#     comment         : XC256109 © Anthony McGeehan  // Bangor, North Down, Northern Ireland (54.6661, -5.7055), United Kingdom // 30m // 07:00h, 2014-07-05 // song // This songster is, probably, the same individual that features in XC256108. Certainly, just one male was presen
#     copyright       : 2014 Anthony McGeehan
#   Duration: 00:00:17.45, start: 0.025057, bitrate: 130 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : LAME3.99r
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Whitethroat/256109.wav':
#   Metadata:
#     INAM            : Common Whitethroat (Sylvia communis)
#     IGNR            : Sylviidae
#     IART            : Anthony McGeehan
#     IPRD            : xeno-canto
#     TIT1            : wleczh
#     ICMT            : XC256109 © Anthony McGeehan  // Bangor, North Down, Northern Ireland (54.6661, -5.7055), United Kingdom // 30m // 07:00h, 2014-07-05 // song // This songster is, probably, the same individual that features in XC256108. Certainly, just one male was presen
#     ICOP            : 2014 Anthony McGeehan
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=    2999kB time=00:00:17.40 bitrate=1411.8kbits/s speed= 720x
# video:0kB audio:2998kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.045343%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-1.5258789e-05  8.5449219e-04  1.0681152e-04 ... -6.3476562e-03
#  -7.4310303e-03 -5.3405762e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# [mp3 @ 0x55b0ee365680] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'audio_mp3/Common Whitethroat/Common Whitethroat-736699.mp3':
#   Metadata:
#     title           : Common Whitethroat (Sylvia communis)
#     genre           : Sylviidae
#     artist          : Andrew Harrop
#     album           : xeno-canto
#     TIT1            : wleczh
#     comment         : XC736699 Â© Andrew Harrop // Aberdaron (near  Uwchmynydd), Gwynedd, Wales (52.7952, -4.7252), United Kingdom // 20m // 12:00h, 2022-07-02 // song // Song phrases from bird in coastal scrub.  /  / bird-seen:yes /  / playback-used:no
#   Duration: 00:00:22.15, start: 0.000000, bitrate: 193 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 192 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Whitethroat/736699.wav':
#   Metadata:
#     INAM            : Common Whitethroat (Sylvia communis)
#     IGNR            : Sylviidae
#     IART            : Andrew Harrop
#     IPRD            : xeno-canto
#     TIT1            : wleczh
#     ICMT            : XC736699 Â© Andrew Harrop // Aberdaron (near  Uwchmynydd), Gwynedd, Wales (52.7952, -4.7252), United Kingdom // 20m // 12:00h, 2022-07-02 // song // Song phrases from bird in coastal scrub.  /  / bird-seen:yes /  / playback-used:no
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=    3812kB time=00:00:22.12 bitrate=1411.4kbits/s speed= 619x
# video:0kB audio:3812kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.010915%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Common Blackbird/Common Blackbird-518779.mp3':
#   Metadata:
#     title           : Common Blackbird (Turdus merula)
#     genre           : Turdidae
#     artist          : Anthony McGeehan
#     album           : xeno-canto
#     TIT1            : frfdsa
#     comment         : XC518779 Â© Anthony McGeehan  // Ireland (near  Bangor), Ards And North Down, Northern Ireland (54.6544, -5.6987), United Kingdom // 60m // 07:30h, 2013-11-24 // adult, call, sex uncertain // Blackbirds are renowned for being alarmists. This clip contai
#   Duration: 00:00:30.43, start: 0.025057, bitrate: 252 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 251 kb/s
#     Metadata:
#       encoder         : LAME3.99r
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Blackbird/518779.wav':
#   Metadata:
#     INAM            : Common Blackbird (Turdus merula)
#     IGNR            : Turdidae
#     IART            : Anthony McGeehan
#     IPRD            : xeno-canto
#     TIT1            : frfdsa
#     ICMT            : XC518779 Â© Anthony McGeehan  // Ireland (near  Bangor), Ards And North Down, Northern Ireland (54.6544, -5.6987), United Kingdom // 60m // 07:30h, 2013-11-24 // adult, call, sex uncertain // Blackbirds are renowned for being alarmists. This clip contai
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=    5239kB time=00:00:30.40 bitrate=1411.5kbits/s speed= 618x
# video:0kB audio:5238kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.020397%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-1.5258789e-05  0.0000000e+00  3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Common Blackbird/Common Blackbird-630362.mp3':
#   Metadata:
#     title           : Common Blackbird (Turdus merula)
#     genre           : Turdidae
#     artist          : Sean Morris
#     album           : xeno-canto
#     TIT1            : frfdsa
#     comment         : XC630362 Â© Sean Morris // Kinloch, Isle of Rum, Scotland (57.0161, -6.2787), United Kingdom // 10m // 21:07h, 2021-03-19 // adult, call, sex uncertain // Nocturnal call /  / bird-seen:no /  / playback-used:no
#   Duration: 00:00:06.19, start: 0.023021, bitrate: 104 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 98 kb/s
#     Metadata:
#       encoder         : LAME3.100
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Blackbird/630362.wav':
#   Metadata:
#     INAM            : Common Blackbird (Turdus merula)
#     IGNR            : Turdidae
#     IART            : Sean Morris
#     IPRD            : xeno-canto
#     TIT1            : frfdsa
#     ICMT            : XC630362 Â© Sean Morris // Kinloch, Isle of Rum, Scotland (57.0161, -6.2787), United Kingdom // 10m // 21:07h, 2021-03-19 // adult, call, sex uncertain // Nocturnal call /  / bird-seen:no /  / playback-used:no
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=    1156kB time=00:00:06.16 bitrate=1536.5kbits/s speed= 692x
# video:0kB audio:1156kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.033619%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[ 2.5467516e-05 -6.5886634e-05 -1.0435980e-04 ... -1.6104782e-04
#   5.1018091e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Common Blackbird/Common Blackbird-631014.mp3':
#   Metadata:
#     title           : Common Blackbird (Turdus merula)
#     genre           : Turdidae
#     artist          : Sean Morris
#     album           : xeno-canto
#     TIT1            : frfdsa
#     comment         : XC631014 Â© Sean Morris // Kinloch, Isle of Rum, Scotland (57.0161, -6.2787), United Kingdom // 10m // 03:00h, 2021-03-20 // adult, call, nocturnal call, sex uncertain //  /  / bird-seen:no /  / playback-used:no
#   Duration: 00:00:05.11, start: 0.023021, bitrate: 105 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 98 kb/s
#     Metadata:
#       encoder         : LAME3.100
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Blackbird/631014.wav':
#   Metadata:
#     INAM            : Common Blackbird (Turdus merula)
#     IGNR            : Turdidae
#     IART            : Sean Morris
#     IPRD            : xeno-canto
#     TIT1            : frfdsa
#     ICMT            : XC631014 Â© Sean Morris // Kinloch, Isle of Rum, Scotland (57.0161, -6.2787), United Kingdom // 10m // 03:00h, 2021-03-20 // adult, call, nocturnal call, sex uncertain //  /  / bird-seen:no /  / playback-used:no
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=     951kB time=00:00:05.06 bitrate=1536.6kbits/s speed= 642x
# video:0kB audio:950kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041100%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-0.00016639 -0.00023289 -0.00027679 ... -0.00029114 -0.00024826
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# [mp3 @ 0x55c2fe93d680] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'audio_mp3/Common Blackbird/Common Blackbird-598974.mp3':
#   Metadata:
#     title           : Common Blackbird (Turdus merula)
#     genre           : Turdidae
#     artist          : Andrew Harrop
#     album           : xeno-canto
#     TIT1            : frfdsa
#     comment         : XC598974 Â© Andrew Harrop // Great Britain (near  Oakham), Rutland, England (52.6696, -0.7266), United Kingdom // 110m // 17:00h, 2020-10-30 // call // Calls from birds going to roost in an urban garden.  /  / bird-seen:yes /  / playback-used:no
#   Duration: 00:00:18.94, start: 0.000000, bitrate: 193 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 192 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Blackbird/598974.wav':
#   Metadata:
#     INAM            : Common Blackbird (Turdus merula)
#     IGNR            : Turdidae
#     IART            : Andrew Harrop
#     IPRD            : xeno-canto
#     TIT1            : frfdsa
#     ICMT            : XC598974 Â© Andrew Harrop // Great Britain (near  Oakham), Rutland, England (52.6696, -0.7266), United Kingdom // 110m // 17:00h, 2020-10-30 // call // Calls from birds going to roost in an urban garden.  /  / bird-seen:yes /  / playback-used:no
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=    3258kB time=00:00:18.91 bitrate=1411.4kbits/s speed= 600x
# video:0kB audio:3258kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013069%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Common Blackbird/Common Blackbird-625892.mp3':
#   Metadata:
#     title           : Common Blackbird (Turdus merula)
#     genre           : Turdidae
#     artist          : Paul Donald
#     album           : xeno-canto
#     TIT1            : frfdsa
#     comment         : XC625892 Â© Paul Donald // Great Britain (near  Southill), Central Bedfordshire, England (52.0638, -0.3155), United Kingdom // 40m // 00:00h, 2021-03-02 // adult, alarm call, sex uncertain //  /  / bird-seen:no /  / playback-used:no
#   Duration: 00:00:13.74, start: 0.025057, bitrate: 182 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 179 kb/s
#     Metadata:
#       encoder         : LAME3.100
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Blackbird/625892.wav':
#   Metadata:
#     INAM            : Common Blackbird (Turdus merula)
#     IGNR            : Turdidae
#     IART            : Paul Donald
#     IPRD            : xeno-canto
#     TIT1            : frfdsa
#     ICMT            : XC625892 Â© Paul Donald // Great Britain (near  Southill), Central Bedfordshire, England (52.0638, -0.3155), United Kingdom // 40m // 00:00h, 2021-03-02 // adult, alarm call, sex uncertain //  /  / bird-seen:no /  / playback-used:no
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=    2358kB time=00:00:13.68 bitrate=1411.4kbits/s speed= 633x
# video:0kB audio:2358kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.017477%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-0.00050354 -0.0009613  -0.00082397 ... -0.00064087 -0.00048828
#  -0.00041199] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Eurasian Blue Tit/Eurasian Blue Tit-187905.mp3':
#   Metadata:
#     title           : Eurasian Blue Tit (Cyanistes caeruleus)
#     genre           : Paridae
#     artist          : david m
#     album           : xeno-canto
#     TIT1            : admpma
#     comment         : XC187905 © david m // Ryedale District (near  Helperthorpe), North Yorkshire, England (54.12, -0.5445), United Kingdom // 80m // 05:17h, 2014-04-28 // male, song // Blue tit song ... not filtered ... parabolic ... /  / bird-seen:yes /  / playback-used:no
#     copyright       : 2014 david m
#   Duration: 00:01:21.82, start: 0.023021, bitrate: 320 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 320 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Eurasian Blue Tit/187905.wav':
#   Metadata:
#     INAM            : Eurasian Blue Tit (Cyanistes caeruleus)
#     IGNR            : Paridae
#     IART            : david m
#     IPRD            : xeno-canto
#     TIT1            : admpma
#     ICMT            : XC187905 © david m // Ryedale District (near  Helperthorpe), North Yorkshire, England (54.12, -0.5445), United Kingdom // 80m // 05:17h, 2014-04-28 // male, song // Blue tit song ... not filtered ... parabolic ... /  / bird-seen:yes /  / playback-used:no
#     ICOP            : 2014 david m
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=   15337kB time=00:01:21.79 bitrate=1536.0kbits/s speed= 574x
# video:0kB audio:15336kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.003095%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-0.0008615  -0.00057581 -0.00069917 ... -0.00076398  0.00075339
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Eurasian Blue Tit/Eurasian Blue Tit-716304.mp3':
#   Metadata:
#     title           : Eurasian Blue Tit (Cyanistes caeruleus)
#     genre           : Paridae
#     artist          : Guy Kirwan
#     album           : xeno-canto
#     TIT1            : admpma
#     comment         : XC716304 Â© Guy Kirwan // Norwich, Norfolk, England (52.6363, 1.2763), United Kingdom // 10m // 07:55h, 2020-05-03 // adult, call //  /  / bird-seen:yes /  / playback-used:no
#   Duration: 00:00:25.21, start: 0.025057, bitrate: 180 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 179 kb/s
#     Metadata:
#       encoder         : LAME3.100
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Eurasian Blue Tit/716304.wav':
#   Metadata:
#     INAM            : Eurasian Blue Tit (Cyanistes caeruleus)
#     IGNR            : Paridae
#     IART            : Guy Kirwan
#     IPRD            : xeno-canto
#     TIT1            : admpma
#     ICMT            : XC716304 Â© Guy Kirwan // Norwich, Norfolk, England (52.6363, 1.2763), United Kingdom // 10m // 07:55h, 2020-05-03 // adult, call //  /  / bird-seen:yes /  / playback-used:no
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=    4338kB time=00:00:25.18 bitrate=1411.3kbits/s speed= 638x
# video:0kB audio:4338kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.008285%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-0.00231934 -0.00279236 -0.00187683 ...  0.00061035 -0.00126648
#  -0.0022583 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Eurasian Blue Tit/Eurasian Blue Tit-599702.mp3':
#   Metadata:
#     title           : Eurasian Blue Tit (Cyanistes caeruleus)
#     genre           : Paridae
#     artist          : Simon Elliott
#     album           : xeno-canto
#     TIT1            : admpma
#     comment         : XC599702 Â© Simon Elliott // Newcastle upon Tyne, Tyne and Wear, England (55.0006, -1.6372), United Kingdom // 90m // 11:00h, 1990-06-03 // begging call, hatchling or nestling // feeding visits, young 19d old; very close, mic in nest box /  / bird-seen:
#   Duration: 00:02:44.26, start: 0.025057, bitrate: 256 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, mono, fltp, 256 kb/s
#     Metadata:
#       encoder         : LAME3.99r
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Eurasian Blue Tit/599702.wav':
#   Metadata:
#     INAM            : Eurasian Blue Tit (Cyanistes caeruleus)
#     IGNR            : Paridae
#     IART            : Simon Elliott
#     IPRD            : xeno-canto
#     TIT1            : admpma
#     ICMT            : XC599702 Â© Simon Elliott // Newcastle upon Tyne, Tyne and Wear, England (55.0006, -1.6372), United Kingdom // 90m // 11:00h, 1990-06-03 // begging call, hatchling or nestling // feeding visits, young 19d old; very close, mic in nest box /  / bird-seen:
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=   14144kB time=00:02:44.20 bitrate= 705.6kbits/s speed= 946x
# video:0kB audio:14144kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.003273%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[ 0.0000000e+00 -6.1035156e-05  3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Eurasian Blue Tit/Eurasian Blue Tit-200870.mp3':
#   Metadata:
#     title           : Eurasian Blue Tit (Cyanistes caeruleus)
#     genre           : Paridae
#     artist          : david m
#     album           : xeno-canto
#     TIT1            : admpma
#     comment         : XC200870 © david m // Ryedale District (near  Helperthorpe), North Yorkshire, England (54.12, -0.5445), United Kingdom // 80m // 07:44h, 2012-06-12 // call, juvenile // Blue tit calls  ... not filtered ... parabolic ... adults feeding young at nest ... /
#     copyright       : 2012 david m
#   Duration: 00:01:55.44, start: 0.023021, bitrate: 320 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 320 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Eurasian Blue Tit/200870.wav':
#   Metadata:
#     INAM            : Eurasian Blue Tit (Cyanistes caeruleus)
#     IGNR            : Paridae
#     IART            : david m
#     IPRD            : xeno-canto
#     TIT1            : admpma
#     ICMT            : XC200870 © david m // Ryedale District (near  Helperthorpe), North Yorkshire, England (54.12, -0.5445), United Kingdom // 80m // 07:44h, 2012-06-12 // call, juvenile // Blue tit calls  ... not filtered ... parabolic ... adults feeding young at nest ... /
#     ICOP            : 2012 david m
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=   21641kB time=00:01:55.41 bitrate=1536.0kbits/s speed= 555x
# video:0kB audio:21641kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002274%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-0.00628092 -0.00533027 -0.00202793 ...  0.00211536  0.0019065
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Eurasian Blue Tit/Eurasian Blue Tit-253687.mp3':
#   Metadata:
#     title           : Eurasian Blue Tit (Cyanistes caeruleus)
#     genre           : Paridae
#     artist          : david m
#     album           : xeno-canto
#     TIT1            : admpma
#     comment         : XC253687 © david m // Ryedale District (near  Helperthorpe), North Yorkshire, England (54.12, -0.5445), United Kingdom // 80m // 05:11h, 2015-05-03 // song // Blue tit song ... not filtered ... parabolic ... /  / bird-seen:yes /  / playback-used:no // al
#     copyright       : 2015 david m
#   Duration: 00:04:10.15, start: 0.023021, bitrate: 320 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 320 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Eurasian Blue Tit/253687.wav':
#   Metadata:
#     INAM            : Eurasian Blue Tit (Cyanistes caeruleus)
#     IGNR            : Paridae
#     IART            : david m
#     IPRD            : xeno-canto
#     TIT1            : admpma
#     ICMT            : XC253687 © david m // Ryedale District (near  Helperthorpe), North Yorkshire, England (54.12, -0.5445), United Kingdom // 80m // 05:11h, 2015-05-03 // song // Blue tit song ... not filtered ... parabolic ... /  / bird-seen:yes /  / playback-used:no // al
#     ICOP            : 2015 david m
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=   46900kB time=00:04:10.12 bitrate=1536.0kbits/s speed= 532x
# video:0kB audio:46899kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001029%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[ 0.00326859  0.00368438  0.00315066 ...  0.0081044  -0.00715105
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Common Chiffchaff/Common Chiffchaff-484654.mp3':
#   Metadata:
#     title           : Common Chiffchaff (Phylloscopus collybita)
#     genre           : Phylloscopidae
#     artist          : Stuart Fisher
#     album           : xeno-canto
#     TIT1            : tammaj
#     comment         : XC484654 Â© Stuart Fisher // Clenchwarton Marsh, Terrington, Norfolk (52.781, 0.353), United Kingdom // 0m // 08:30h, 2019-07-03 // male, song //  /  / bird-seen:no /  / playback-used:no // also:  Common Whitethroat, European Robin
#   Duration: 00:02:02.76, start: 0.023021, bitrate: 320 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 320 kb/s
#     Metadata:
#       encoder         : LAME3.99r
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Common Chiffchaff/484654.wav':
#   Metadata:
#     INAM            : Common Chiffchaff (Phylloscopus collybita)
#     IGNR            : Phylloscopidae
#     IART            : Stuart Fisher
#     IPRD            : xeno-canto
#     TIT1            : tammaj
#     ICMT            : XC484654 Â© Stuart Fisher // Clenchwarton Marsh, Terrington, Norfolk (52.781, 0.353), United Kingdom // 0m // 08:30h, 2019-07-03 // male, song //  /  / bird-seen:no /  / playback-used:no // also:  Common Whitethroat, European Robin
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# ...
#     ICOP            : 2015 david m
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=   22784kB time=00:02:01.51 bitrate=1536.0kbits/s speed= 582x
# video:0kB audio:22784kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002263%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[1.1418349e-03 1.4586103e-03 1.1346799e-03 ... 8.4555191e-05 4.7891561e-04
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# [mp3 @ 0x55f590a04680] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'audio_mp3/Corn Bunting/Corn Bunting-562542.mp3':
#   Metadata:
#     title           : Corn Bunting (Emberiza calandra)
#     genre           : Emberizidae
#     artist          : Michael Weedon
#     album           : xeno-canto
#     TIT1            : cdegpv
#     comment         : XC562542 Â© Michael Weedon // Great Britain (near  Holme), Cambridgeshire, England (52.497, -0.1887), United Kingdom // 0m // 20:30h, 2020-05-25 // adult, male, song //  /  / bird-seen:yes /  / playback-used:no // also:  Eurasian Skylark, Sedge Warbler,
#   Duration: 00:00:31.88, start: 0.000000, bitrate: 161 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 160 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Corn Bunting/562542.wav':
#   Metadata:
#     INAM            : Corn Bunting (Emberiza calandra)
#     IGNR            : Emberizidae
#     IART            : Michael Weedon
#     IPRD            : xeno-canto
#     TIT1            : cdegpv
#     ICMT            : XC562542 Â© Michael Weedon // Great Britain (near  Holme), Cambridgeshire, England (52.497, -0.1887), United Kingdom // 0m // 20:30h, 2020-05-25 // adult, male, song //  /  / bird-seen:yes /  / playback-used:no // also:  Eurasian Skylark, Sedge Warbler,
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=    5972kB time=00:00:31.84 bitrate=1536.1kbits/s speed= 592x
# video:0kB audio:5972kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007948%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# [mp3 @ 0x563ac9d3d680] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'audio_mp3/Corn Bunting/Corn Bunting-664197.mp3':
#   Metadata:
#     title           : Corn Bunting (Emberiza calandra)
#     genre           : Emberizidae
#     artist          : Andrew Harrop
#     album           : xeno-canto
#     TIT1            : cdegpv
#     comment         : XC664197 Â© Andrew Harrop // Great Britain (near  Frampton), Lincolnshire, England (52.9314, 0.0189), United Kingdom // 10m // 08:30h, 2021-07-21 // song // Song phrase from bird in hawthorn between marsh and farmland.  /  / bird-seen:yes /  / playback-
#   Duration: 00:00:03.89, start: 0.000000, bitrate: 200 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 192 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Corn Bunting/664197.wav':
#   Metadata:
#     INAM            : Corn Bunting (Emberiza calandra)
#     IGNR            : Emberizidae
#     IART            : Andrew Harrop
#     IPRD            : xeno-canto
#     TIT1            : cdegpv
#     ICMT            : XC664197 Â© Andrew Harrop // Great Britain (near  Frampton), Lincolnshire, England (52.9314, 0.0189), United Kingdom // 10m // 08:30h, 2021-07-21 // song // Song phrase from bird in hawthorn between marsh and farmland.  /  / bird-seen:yes /  / playback-
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=     666kB time=00:00:03.86 bitrate=1412.1kbits/s speed= 326x
# video:0kB audio:666kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.066570%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# [mp3 @ 0x55a7c9846680] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'audio_mp3/Corn Bunting/Corn Bunting-534817.mp3':
#   Metadata:
#     title           : Corn Bunting (Emberiza calandra)
#     genre           : Emberizidae
#     artist          : Andrew Harrop
#     album           : xeno-canto
#     TIT1            : cdegpv
#     comment         : XC534817 Â© Andrew Harrop // Great Britain (near  Holbeach Saint Marks), Lincolnshire, England (52.8605, 0.0265), United Kingdom // 0m // 09:00h, 2020-03-16 // song // Song from bird on telegraph wires.  /  / bird-seen:yes /  / playback-used:no
#   Duration: 00:00:10.24, start: 0.000000, bitrate: 195 kb/s
#     Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 192 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Corn Bunting/534817.wav':
#   Metadata:
#     INAM            : Corn Bunting (Emberiza calandra)
#     IGNR            : Emberizidae
#     IART            : Andrew Harrop
#     IPRD            : xeno-canto
#     TIT1            : cdegpv
#     ICMT            : XC534817 Â© Andrew Harrop // Great Britain (near  Holbeach Saint Marks), Lincolnshire, England (52.8605, 0.0265), United Kingdom // 0m // 09:00h, 2020-03-16 // song // Song from bird on telegraph wires.  /  / bird-seen:yes /  / playback-used:no
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=    1760kB time=00:00:10.21 bitrate=1411.5kbits/s speed= 591x
# video:0kB audio:1760kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.024310%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Corn Bunting/Corn Bunting-659616.mp3':
#   Metadata:
#     title           : Corn Bunting (Emberiza calandra)
#     genre           : Emberizidae
#     artist          : Simon Elliott
#     album           : xeno-canto
#     TIT1            : cdegpv
#     comment         : XC659616 Â© Simon Elliott // near  Rufforth, York, England (53.9693, -1.2157), United Kingdom // 10m // 05:40h, 2021-06-27 // alarm call, male // alarm to aerial predator: Hobby Falco subbuteo flying over /  / bird-seen:yes /  / playback-used:no
#   Duration: 00:00:02.88, start: 0.023021, bitrate: 335 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, mono, fltp, 320 kb/s
#     Metadata:
#       encoder         : LAME3.99r
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Corn Bunting/659616.wav':
#   Metadata:
#     INAM            : Corn Bunting (Emberiza calandra)
#     IGNR            : Emberizidae
#     IART            : Simon Elliott
#     IPRD            : xeno-canto
#     TIT1            : cdegpv
#     ICMT            : XC659616 Â© Simon Elliott // near  Rufforth, York, England (53.9693, -1.2157), United Kingdom // 10m // 05:40h, 2021-06-27 // alarm call, male // alarm to aerial predator: Hobby Falco subbuteo flying over /  / bird-seen:yes /  / playback-used:no
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=     268kB time=00:00:02.85 bitrate= 769.2kbits/s speed= 142x
# video:0kB audio:267kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.160000%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-9.8618664e-05  1.4736273e-03  3.6361059e-03 ...  9.0171229e-03
#   1.1637948e-02  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/obasekore/anaconda3/envs/RL_local --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mp3, from 'audio_mp3/Corn Bunting/Corn Bunting-348805.mp3':
#   Metadata:
#     title           : Corn Bunting (Emberiza calandra)
#     genre           : Emberizidae
#     artist          : Mark Lewis
#     album           : xeno-canto
#     TIT1            : cdegpv
#     comment         : XC348805 © Mark Lewis // Auchnagatt, Aberdeenshire, Scotland (57.4651, -2.1149), United Kingdom // 70m // 08:00h, 2016-11-09 // song
#     copyright       : 2016 Mark Lewis
#   Duration: 00:00:07.80, start: 0.023021, bitrate: 92 kb/s
#     Stream #0:0: Audio: mp3, 48000 Hz, mono, fltp, 88 kb/s
#     Metadata:
#       encoder         : LAME3.98r
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio_wav/Corn Bunting/348805.wav':
#   Metadata:
#     INAM            : Corn Bunting (Emberiza calandra)
#     IGNR            : Emberizidae
#     IART            : Mark Lewis
#     IPRD            : xeno-canto
#     TIT1            : cdegpv
#     ICMT            : XC348805 © Mark Lewis // Auchnagatt, Aberdeenshire, Scotland (57.4651, -2.1149), United Kingdom // 70m // 08:00h, 2016-11-09 // song
#     ICOP            : 2016 Mark Lewis
#     ISFT            : Lavf58.12.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s
#     Metadata:
#       encoder         : Lavc58.18.100 pcm_s16le
# size=     728kB time=00:00:07.76 bitrate= 768.4kbits/s speed= 273x
# video:0kB audio:728kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.046438%
# /home/obasekore/anaconda3/envs/RL_local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Pass y=[-5.6990120e-05 -1.3148478e-04 -1.4485880e-04 ... -9.2732185e-04
#  -8.7798398e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df = pd.DataFrame(data_list)
df.to_csv("datasets/dataset.csv")
df
# Out:
#     id audio_id                  class t_start_sec t_end_sec
# 0    0   199781     Common Whitethroat           0         5
# 1    1   492805     Common Whitethroat           0         5
# 2    2   619033     Common Whitethroat           0         5
# 3    3   256109     Common Whitethroat           0         5
# 4    4   736699     Common Whitethroat           0         5
# 5    5   518779       Common Blackbird           0         5
# 6    6   630362       Common Blackbird           0         5
# 7    7   631014       Common Blackbird           0         5
# 8    8   598974       Common Blackbird           0         5
# 9    9   625892       Common Blackbird           0         5
# 10  10   187905      Eurasian Blue Tit           0         5
# 11  11   716304      Eurasian Blue Tit           0         5
# 12  12   599702      Eurasian Blue Tit           0         5
# 13  13   200870      Eurasian Blue Tit           0         5
# 14  14   253687      Eurasian Blue Tit           0         5
# 15  15   484654      Common Chiffchaff           0         5
# 16  16   412592      Common Chiffchaff           0         5
# 17  17   637771      Common Chiffchaff           0         5
# 18  18   203983      Common Chiffchaff           0         5
# 19  19   549386      Common Chiffchaff           0         5
# 20  20   164533  Eurasian Tree Sparrow           0         5
# 21  21   182243  Eurasian Tree Sparrow           0         5
# 22  22   186172  Eurasian Tree Sparrow           0         5
# 23  23   263657  Eurasian Tree Sparrow           0         5
# 24  24   186173  Eurasian Tree Sparrow           0         5
# 25  25   561974              Great Tit           0         5
# 26  26   619611              Great Tit           0         5
# 27  27   330152              Great Tit           0         5
# 28  28   696256              Great Tit           0         5
# 29  29   720773              Great Tit           0         5
# 30  30   592912         Willow Warbler           0         5
# 31  31   645884         Willow Warbler           0         5
# 32  32   565217         Willow Warbler           0         5
# 33  33   582302         Willow Warbler           0         5
# 34  34   395572         Willow Warbler           0         5
# 35  35   213099           Yellowhammer           0         5
# 36  36   346458           Yellowhammer           0         5
# 37  37   256396           Yellowhammer           0         5
# 38  38   145533           Yellowhammer           0         5
# 39  39   256906           Yellowhammer           0         5
# 40  40   181529       Common Chaffinch           0         5
# 41  41   179753       Common Chaffinch           0         5
# 42  42   729572       Common Chaffinch           0         5
# 43  43   182244       Common Chaffinch           0         5
# 44  44   294473       Common Chaffinch           0         5
# 45  45   562542           Corn Bunting           0         5
# 46  46   664197           Corn Bunting           0         5
# 47  47   534817           Corn Bunting           0         5
# 48  48   659616           Corn Bunting           0         5
# 49  49   348805           Corn Bunting           0         5

# %%
df.groupby("class").head(3)

# %% [markdown]
# ### copy all images and annotations in the temporary dataset folder to the
# ### actual dataset

# %%
pwd
# Out:
# 'g:\\birdSounds\\Mask_RCNN\\samples\\birdsounds'

# %%
# !mkdir ${PWD}/datasets/images
# !mkdir ${PWD}/datasets/annots
# !find ${PWD}/temp_datasets -name '*.png' -exec cp -t ${PWD}/datasets/images {} +
# !cp ${PWD}/temp_datasets/annots/*.xml ${PWD}/datasets/annots/*.xml
# Out:
# File not found - '*.png'

# %% [markdown]
# ## Train
